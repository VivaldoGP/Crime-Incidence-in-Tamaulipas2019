# %% [markdown]
# ## Incidencia Delictiva desagregado por Municipio de Hechos del Estado de Tamaulipas durante el periodo de Enero a Diciembre de 2019

# %% [markdown]
# ### Librerías

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Datos abiertos del Gobierno de México

# %%
crime = pd.read_csv('https://www.tamaulipas.gob.mx/datosabiertos/datos_abiertos/incidencia-delictiva-por-municipio-de-hechos/descargar',encoding='ISO-8859-1')

# %%
crime
# Out:
#              MUNICIPIO  ENERO  FEBRERO   MARZO  ABRIL  MAYO  JUNIO  JULIO  \
# 0              Abasolo      3         3      2      5     6      2      4
# 1               Aldama     22        23     17     22    26     16     26
# 2             Altamira    258       231    254    242   311    289    289
# 3      Antiguo Morelos      3         4      5      4     5      5      4
# 4               Burgos      2         2      1      2     0      3      4
# 5           Bustamante      0         3      4      1     4      1      3
# 6              Camargo     14         6      6     10    11      6      4
# 7                Casas      1         0      0      2     5      2      7
# 8        Ciudad Madero    176       203    171    243   248    213    178
# 9             Cruillas      1         0      0      1     1      0      2
# 10            El Mante    108       103     95     90   116    125     96
# 11        Gmez Faras      0         3      7      9    10      4      6
# ...

# %% [markdown]
# ### Shape de Municipios

# %%
mun = gpd.read_file("C:/Users/Usuario/python/delitos/mun2019gw/mun2019gw.shp",encoding='utf-8')

# %%
mun.head()
# Out:
#   CVEGEO CVE_ENT CVE_MUN         NOM_ENT           AREA   PERIMETER  COV_  \
# 0  01001      01     001  Aguascalientes  116635.924760  256.631026     0
# 1  01002      01     002  Aguascalientes   54337.426596  192.096428     1
# 2  01003      01     003  Aguascalientes   92335.783227  171.636168     2
# 3  01004      01     004  Aguascalientes   12838.354453   73.352682     3
# 4  01005      01     005  Aguascalientes   49989.509147  163.500810     4
#
#    COV_ID         NOM_MUN                                           geometry
# 0       1  Aguascalientes  POLYGON ((-102.10641 22.06035, -102.10368 22.0...
# 1       2        Asientos  POLYGON ((-102.05189 22.29144, -102.05121 22.2...
# 2       3        Calvillo  POLYGON ((-102.68569 22.09963, -102.69087 22.0...
# 3       4           Cosío  POLYGON ((-102.28787 22.41649, -102.28753 22.4...
# 4       5     Jesús María  POLYGON ((-102.33568 22.05067, -102.33348 22.0...

# %% [markdown]
# ### Filtrado de los datos

# %%
tamps = mun[mun.NOM_ENT=="Tamaulipas"]

# %%
tamps.rename(columns={"NOM_MUN":"MUNICIPIO"})
# Out:
#      CVEGEO CVE_ENT CVE_MUN     NOM_ENT           AREA   PERIMETER  COV_  \
# 1986  28001      28     001  Tamaulipas  183887.697259  274.978098  1986
# 1987  28002      28     002  Tamaulipas  377822.688014  371.286898  1987
# 1988  28003      28     003  Tamaulipas  164436.567516  260.469646  1988
# 1989  28004      28     004  Tamaulipas   57608.448482  140.934561  1989
# 1990  28005      28     005  Tamaulipas  188543.001035  308.899788  1990
# 1991  28006      28     006  Tamaulipas  143440.441822  259.756218  1991
# 1992  28007      28     007  Tamaulipas   92227.678531  173.240081  1992
# 1993  28008      28     008  Tamaulipas  298127.644709  502.680615  1993
# 1994  28009      28     009  Tamaulipas    4793.069754   33.124282  1994
# 1995  28010      28     010  Tamaulipas  186958.344202  241.508201  1995
# 1996  28011      28     011  Tamaulipas   72243.581170  152.199024  1996
# 1997  28012      28     012  Tamaulipas  320791.306336  415.567632  1997
# ...

# %%
#len(tamps)
tamps.plot(figsize=(10,10));

# %% [markdown]
# ### Delitos por municipio asociado a su geometría

# %%
tamps_crime = pd.merge(crime,tamps,on='MUNICIPIO')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-59c5ff1a50f5> in <module>
# ----> 1 tamps_crime = pd.merge(crime,tamps,on='MUNICIPIO')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
# ...
